# %%
import requests
from flask import jsonify

# %%
payload = {"Vector": [1,2,3,4,5,6,7,8]}
resp = requests.get("http://127.0.0.1:6060/Encrypt", json=payload)

# %%
resp.text
# Out:
# "{'content': b'...'}"

# %%
Dataset = requests.get("http://127.0.0.1:6060/getdata")

# %%
Dataset.text
# Out:
# "{'Pregnancies': {'content': b'...'}, 'Glucose': {'content': b'...'}, 'BloodPressure': {'content': b'...'}, 'SkinThickness': {'content': b'...'}, 'Insulin': {'content': b'...'}, 'BMI': {'content': b'...'}, 'DiabetesPedigreeFunction': {'content': b'...'}, 'Age': {'content': b'...'}, 'Outcome': {'content': b'...'}}"
